# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df_data_base = pd.read_csv("../data/originals/PROD_TERMIN_ART_SIN_9.csv")
df_data_base_imp = pd.read_csv("../data/originals/FACTOR_IMPACTO.csv")
df_data_new = pd.read_csv("../data/process/all_data_api.csv")

# %%
df_data_base["TITULO"] = df_data_base["TITULO"].str.lower().str.strip().str.replace(":", "").str.replace("-", "")
df_data_new["title"] = df_data_new["title"].str.lower().str.strip().str.replace(":", "").str.replace("-", "")

# %%
df_data_new["TITULO"] = df_data_new["title"]

# %%
result = pd.merge(df_data_base, df_data_new, on="TITULO", how="inner")

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2355 entries, 0 to 2354
# Data columns (total 83 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   IDDECINVPROYECTOPRODTERMIN    2355 non-null   int64
#  1   IDDECINVPROYECTO              2355 non-null   float64
#  2   IDDECINVTIPOPRODUCTOESPERADO  2355 non-null   int64
#  3   TITULO                        2355 non-null   object
#  4   ANIO                          2355 non-null   int64
#  5   VOLUMEN                       2324 non-null   float64
#  6   PAGINAS                       2316 non-null   object
#  7   NOMBREREVISTA                 2244 non-null   object
#  8   ISINDEX                       2257 non-null   float64
#  9   BDREVISTA                     2149 non-null   float64
#  10  ISSN                          2136 non-null   object
#  11  FACTIMPACTO                   591 non-null    object
#  12  EDITORIAL                     84 non-null     object
#  13  ESTADOPUBLICACION             2248 non-null   float64
#  14  ESPECIFICACION                0 non-null      object
#  15  URL                           2167 non-null   object
#  16  ULTIMO_CAMBIO                 2355 non-null   object
#  17  NEVENTO                       91 non-null     object
#  18  LEVENTO                       91 non-null     object
#  19  FEVENTO                       455 non-null    object
#  20  ADJUNTO                       2036 non-null   object
#  21  FECHAPUBLICACION              2027 non-null   object
#  22  RESUMEN                       2276 non-null   object
#  23  KEYS                          2272 non-null   object
#  24  ASIST_OBJETIV                 0 non-null      object
#  25  INNOVA_VERIFIC                0 non-null      float64
#  26  LOGROS_SISTEMAC               0 non-null      object
#  27  RETOS_COMUNIC                 0 non-null      object
#  28  IDUNIDAD                      365 non-null    float64
#  29  TIPOLAB                       0 non-null      float64
#  30  MARCA                         0 non-null      float64
#  31  MODELO                        0 non-null      float64
#  32  SERIE                         0 non-null      float64
#  33  INVENTARIO                    0 non-null      float64
#  34  ESTADO                        365 non-null    float64
#  35  FRECUENCIA                    365 non-null    float64
#  36  FVENCIMIENTO                  365 non-null    object
#  37  SJR                           1896 non-null   object
#  38  CUARTIL                       2107 non-null   object
#  39  IDDECINVREVISTA               2127 non-null   float64
#  40  APROBADO                      2355 non-null   object
#  41  IDDECINVMOTIVOPRODTERMIN      1733 non-null   float64
#  42  OBSERVACIONARPOB              0 non-null      float64
#  43  IDPUBLICACIONPERSONA          383 non-null    float64
#  44  ADJUNTO2                      327 non-null    object
#  45  ADJUNTO3                      154 non-null    object
#  46  ADJUNTO4                      163 non-null    object
#  47  CODIGOPRODUCTO                24 non-null     object
#  48  TIPOTESIS                     365 non-null    object
#  49  REVISIONPARES                 442 non-null    object
#  50  DOI                           1770 non-null   object
#  51  INVENTOR                      0 non-null      object
#  52  SUBCLASE                      2355 non-null   int64
#  53  URLREVISTA                    315 non-null    object
#  54  MATERIAINTEGRADORA            2355 non-null   object
#  55  NUMEROSOLICITUD               0 non-null      object
#  56  OBJGENERAL                    0 non-null      float64
#  57  ESTAELIMINADO                 2355 non-null   object
#  58  url                           2355 non-null   object
#  59  doi                           2252 non-null   object
#  60  url_doi                       2252 non-null   object
#  61  eid                           2355 non-null   object
#  62  title                         2355 non-null   object
#  63  abstract                      2330 non-null   object
#  64  key_words                     2071 non-null   object
#  65  cuartil                       0 non-null      float64
#  66  volume                        2011 non-null   object
#  67  authors                       2349 non-null   object
#  68  affiliations                  2349 non-null   float64
#  69  issn                          2041 non-null   object
#  70  magazine                      1955 non-null   object
#  71  citeScore                     1897 non-null   float64
#  72  citations_scopus_count        2355 non-null   float64
#  73  language                      2330 non-null   object
#  74  coverDate                     2355 non-null   object
#  75  publication_year              2355 non-null   float64
#  76  page_raw                      1347 non-null   object
#  77  page_count                    1345 non-null   float64
#  78  scimago_factor_SJR            1854 non-null   object
#  79  scimago_SJR_Best_Quartile     1872 non-null   object
#  80  eid_original_input            2355 non-null   object
#  81  error_message                 0 non-null      float64
#  82  año                           2337 non-null   float64
# dtypes: float64(27), int64(4), object(52)
# memory usage: 1.5+ MB

# %%
result["TITULO"].value_counts()
# Out:
# TITULO
# building academic branding the digital branding as academic footprint                                                                                                           4
# adaptive evacuation management system based on monitoring techniques                                                                                                            4
# humanmachine musical composition in realtime based on emotions through a fuzzy logic approach                                                                                   4
# overcoming limitations of polymer additive manufacturing for snapfit joint design and part assembly                                                                             4
# development of sociodemographic indicators for modeling the household solid waste generation in guayaquil (ecuador) quantification, characterization and energy valorization    3
#                                                                                                                                                                                ..
# laserinduced subwavelength structures by microdroplet superlens                                                                                                                 1
# batch process control and monitoring a dual statis and parallel coordinates (dspc) approach                                                                                     1
# topological characterization of gelfand and zero dimensional semiring                                                                                                           1
# spondylids of eastern pacific ocean                                                                                                                                             1
# spat production of the rock oyster striostrea prismatica (gray, 1825)                                                                                                           1
# Name: count, Length: 2076, dtype: int64

# %%
result[result["title"] == "Preface"]
# Out:
# Empty DataFrame
# Columns: [IDDECINVPROYECTOPRODTERMIN, IDDECINVPROYECTO, IDDECINVTIPOPRODUCTOESPERADO, TITULO, ANIO, VOLUMEN, PAGINAS, NOMBREREVISTA, ISINDEX, BDREVISTA, ISSN, FACTIMPACTO, EDITORIAL, ESTADOPUBLICACION, ESPECIFICACION, URL, ULTIMO_CAMBIO, NEVENTO, LEVENTO, FEVENTO, ADJUNTO, FECHAPUBLICACION, RESUMEN, KEYS, ASIST_OBJETIV, INNOVA_VERIFIC, LOGROS_SISTEMAC, RETOS_COMUNIC, IDUNIDAD, TIPOLAB, MARCA, MODELO, SERIE, INVENTARIO, ESTADO, FRECUENCIA, FVENCIMIENTO, SJR, CUARTIL, IDDECINVREVISTA, APROBADO, IDDECINVMOTIVOPRODTERMIN, OBSERVACIONARPOB, IDPUBLICACIONPERSONA, ADJUNTO2, ADJUNTO3, ADJUNTO4, CODIGOPRODUCTO, TIPOTESIS, REVISIONPARES, DOI, INVENTOR, SUBCLASE, URLREVISTA, MATERIAINTEGRADORA, NUMEROSOLICITUD, OBJGENERAL, ESTAELIMINADO, url, doi, url_doi, eid, title, abstract, key_words, cuartil, volume, authors, affiliations, issn, magazine, citeScore, citations_scopus_count, language, coverDate, publication_year, page_raw, page_count, scimago_factor_SJR, scimago_SJR_Best_Quartile, eid_original_input, error_message, año]
# Index: []

# %%
sql_update_commands = []
TABLE_NAME = "ESPOL.TBL_DEC_INV_PROYECTO_PROD_TERMIN"

# Mapeo de las columnas de origen (df_data_new) a las de destino (df_data_base)
column_mapping = {
    'doi': 'DOI',
    'issn': 'ISSN',
    'page_raw': 'PAGINAS',
    'abstract': 'RESUMEN',
    'key_words': 'KEYS',
    'volume': 'VOLUMEN'
}

# %%
# Función para escapar caracteres especiales en SQL (especialmente comillas simples)
def escape_sql(value):
    if value is None or pd.isna(value):
        return "NULL"
    # Reemplaza una comilla simple ' por dos comillas simples ''
    return str(value).replace("'", "''")

# %%
# Función para validar si un valor puede convertirse a entero
def is_valid_integer(value):
    try:
        int(value)
        return True
    except (ValueError, TypeError):
        return False

# %%
print("Procesando registros para generar script de actualización...")

# Iteramos sobre cada fila del DataFrame resultante del merge
for index, row in result.iterrows():
    # Obtenemos el ID para la cláusula WHERE. Si no hay ID, no podemos actualizar.
    record_id = row['IDDECINVPROYECTOPRODTERMIN']
    if pd.isna(record_id):
        print(f"  - Omitiendo fila con título '{row['title']}' porque no se encontró un IDDECINVPROYECTOPRODTERMIN correspondiente.")
        continue

    # Lista para guardar las partes SET de la consulta para este registro específico
    set_clauses = []

    # Aplicamos la lógica de actualización para cada campo
    for source_col, dest_col in column_mapping.items():
        new_value = row[source_col]
        old_value = row[dest_col]

        # La condición clave:
        # Si el valor antiguo (de la BD) es NULO/VACÍO y el valor nuevo SÍ tiene contenido...
        if pd.isna(old_value) and pd.notna(new_value):
            # Validación especial para VOLUMEN
            if dest_col == 'VOLUMEN':
                if is_valid_integer(new_value):
                    # Si es válido como entero, lo convertimos
                    set_clauses.append(f"{dest_col} = {int(new_value)}")
                else:
                    # Si no es válido, lo ignoramos y mostramos el mensaje
                    print(f"  ! Ignorando VOLUMEN para DOI '{row['doi']}': valor '{new_value}' no es entero válido")
                    continue
            else:
                # Para otros campos, aplicamos escape normal
                set_clauses.append(f"{dest_col} = '{escape_sql(new_value)}'")

    # Si hay al menos un campo para actualizar en este registro...
    if set_clauses:
        # ...construimos la sentencia UPDATE completa.
        update_statement = f"UPDATE {TABLE_NAME} SET {', '.join(set_clauses)} WHERE IDDECINVPROYECTOPRODTERMIN = {int(record_id)};"
        sql_update_commands.append(update_statement)
        print(f"  + Generando UPDATE para ID: {int(record_id)}")
# Out:
# Procesando registros para generar script de actualización...
#   + Generando UPDATE para ID: 2304
#   + Generando UPDATE para ID: 2306
#   + Generando UPDATE para ID: 2336
#   + Generando UPDATE para ID: 2338
#   + Generando UPDATE para ID: 2354
#   + Generando UPDATE para ID: 2355
#   ! Ignorando VOLUMEN para DOI '10.1109/CVPRW50498.2020.00041': valor '2020-June' no es entero válido
#   + Generando UPDATE para ID: 3296
#   + Generando UPDATE para ID: 2388
#   + Generando UPDATE para ID: 2402
#   + Generando UPDATE para ID: 2405
#   + Generando UPDATE para ID: 2553
#   + Generando UPDATE para ID: 2449
#   + Generando UPDATE para ID: 2512
#   + Generando UPDATE para ID: 2515
#   + Generando UPDATE para ID: 2518
#   + Generando UPDATE para ID: 2520
#   ! Ignorando VOLUMEN para DOI '10.18687/LACCEI2018.1.1.78': valor '2018-July' no es entero válido
#   + Generando UPDATE para ID: 2539
#   + Generando UPDATE para ID: 2545
#   + Generando UPDATE para ID: 2570
#   + Generando UPDATE para ID: 2571
#   + Generando UPDATE para ID: 2572
#   + Generando UPDATE para ID: 2633
#   + Generando UPDATE para ID: 6733
#   + Generando UPDATE para ID: 2673
#   + Generando UPDATE para ID: 2700
#   + Generando UPDATE para ID: 2729
#   + Generando UPDATE para ID: 2948
#   + Generando UPDATE para ID: 2949
#   + Generando UPDATE para ID: 2951
#   + Generando UPDATE para ID: 2952
#   + Generando UPDATE para ID: 2953
#   + Generando UPDATE para ID: 2954
#   + Generando UPDATE para ID: 2957
#   + Generando UPDATE para ID: 2959
#   + Generando UPDATE para ID: 2999
#   + Generando UPDATE para ID: 3000
#   + Generando UPDATE para ID: 3015
#   + Generando UPDATE para ID: 6734
#   + Generando UPDATE para ID: 3076
#   + Generando UPDATE para ID: 3098
#   + Generando UPDATE para ID: 3103
#   + Generando UPDATE para ID: 3117
#   + Generando UPDATE para ID: 3118
#   + Generando UPDATE para ID: 3119
#   + Generando UPDATE para ID: 3120
#   + Generando UPDATE para ID: 3127
#   + Generando UPDATE para ID: 3128
#   + Generando UPDATE para ID: 3129
#   + Generando UPDATE para ID: 3188
#   + Generando UPDATE para ID: 3190
#   + Generando UPDATE para ID: 3210
#   + Generando UPDATE para ID: 3256
#   ! Ignorando VOLUMEN para DOI '10.1109/CVPRW50498.2020.00056': valor '2020-June' no es entero válido
#   + Generando UPDATE para ID: 3291
#   ! Ignorando VOLUMEN para DOI '10.1109/IWSSIP48289.2020.9145121': valor '2020-July' no es entero válido
#   + Generando UPDATE para ID: 3293
#   + Generando UPDATE para ID: 3308
#   + Generando UPDATE para ID: 3312
#   + Generando UPDATE para ID: 3328
#   + Generando UPDATE para ID: 3336
#   + Generando UPDATE para ID: 3414
#   + Generando UPDATE para ID: 3433
#   + Generando UPDATE para ID: 3466
#   + Generando UPDATE para ID: 3474
#   + Generando UPDATE para ID: 3475
#   + Generando UPDATE para ID: 3476
#   + Generando UPDATE para ID: 3485
#   + Generando UPDATE para ID: 3489
#   + Generando UPDATE para ID: 3519
#   + Generando UPDATE para ID: 3526
#   + Generando UPDATE para ID: 3608
#   + Generando UPDATE para ID: 6398
#   + Generando UPDATE para ID: 6400
#   + Generando UPDATE para ID: 3623
#   + Generando UPDATE para ID: 3626
#   + Generando UPDATE para ID: 3627
#   + Generando UPDATE para ID: 3630
#   + Generando UPDATE para ID: 3631
#   + Generando UPDATE para ID: 3634
#   + Generando UPDATE para ID: 3635
#   + Generando UPDATE para ID: 3666
#   + Generando UPDATE para ID: 3670
#   + Generando UPDATE para ID: 3673
#   + Generando UPDATE para ID: 3674
#   + Generando UPDATE para ID: 3682
#   + Generando UPDATE para ID: 3695
#   + Generando UPDATE para ID: 3705
#   + Generando UPDATE para ID: 3706
#   + Generando UPDATE para ID: 3707
#   + Generando UPDATE para ID: 3725
#   + Generando UPDATE para ID: 3730
#   + Generando UPDATE para ID: 3734
#   + Generando UPDATE para ID: 3746
#   + Generando UPDATE para ID: 3755
#   + Generando UPDATE para ID: 3755
#   + Generando UPDATE para ID: 3805
#   + Generando UPDATE para ID: 3806
#   + Generando UPDATE para ID: 3810
#   + Generando UPDATE para ID: 3811
#   + Generando UPDATE para ID: 3818
#   + Generando UPDATE para ID: 3851
#   + Generando UPDATE para ID: 3856
#   + Generando UPDATE para ID: 3856
#   + Generando UPDATE para ID: 3884
#   + Generando UPDATE para ID: 3918
#   + Generando UPDATE para ID: 3922
#   + Generando UPDATE para ID: 3927
#   + Generando UPDATE para ID: 3969
#   + Generando UPDATE para ID: 3969
#   + Generando UPDATE para ID: 4033
#   + Generando UPDATE para ID: 4042
#   + Generando UPDATE para ID: 4068
#   + Generando UPDATE para ID: 4069
#   + Generando UPDATE para ID: 4070
#   + Generando UPDATE para ID: 4071
#   + Generando UPDATE para ID: 4094
#   + Generando UPDATE para ID: 4095
#   + Generando UPDATE para ID: 4098
#   + Generando UPDATE para ID: 4119
#   + Generando UPDATE para ID: 4123
#   + Generando UPDATE para ID: 4129
#   + Generando UPDATE para ID: 4136
#   + Generando UPDATE para ID: 4181
#   + Generando UPDATE para ID: 4182
#   + Generando UPDATE para ID: 4183
#   + Generando UPDATE para ID: 4184
#   + Generando UPDATE para ID: 4216
#   + Generando UPDATE para ID: 4245
#   + Generando UPDATE para ID: 4282
#   + Generando UPDATE para ID: 4306
#   + Generando UPDATE para ID: 4317
#   + Generando UPDATE para ID: 4326
#   + Generando UPDATE para ID: 4335
#   + Generando UPDATE para ID: 4343
#   + Generando UPDATE para ID: 4344
#   + Generando UPDATE para ID: 4355
#   + Generando UPDATE para ID: 4358
#   + Generando UPDATE para ID: 6340
#   ! Ignorando VOLUMEN para DOI '10.1109/ETCM.2017.8247450': valor '2017-January' no es entero válido
#   + Generando UPDATE para ID: 4509
#   + Generando UPDATE para ID: 4564
#   + Generando UPDATE para ID: 4551
#   + Generando UPDATE para ID: 4608
#   + Generando UPDATE para ID: 4709
#   + Generando UPDATE para ID: 4709
#   + Generando UPDATE para ID: 4725
#   + Generando UPDATE para ID: 4731
#   + Generando UPDATE para ID: 4738
#   + Generando UPDATE para ID: 4768
#   + Generando UPDATE para ID: 4770
#   + Generando UPDATE para ID: 4772
#   + Generando UPDATE para ID: 4774
#   + Generando UPDATE para ID: 4778
#   + Generando UPDATE para ID: 4841
#   + Generando UPDATE para ID: 4864
#   + Generando UPDATE para ID: 4879
#   + Generando UPDATE para ID: 4909
#   + Generando UPDATE para ID: 4926
#   + Generando UPDATE para ID: 4927
#   + Generando UPDATE para ID: 4939
#   + Generando UPDATE para ID: 4951
#   + Generando UPDATE para ID: 4952
#   + Generando UPDATE para ID: 4965
#   + Generando UPDATE para ID: 4994
#   + Generando UPDATE para ID: 5002
#   + Generando UPDATE para ID: 5006
#   + Generando UPDATE para ID: 5007
#   + Generando UPDATE para ID: 5128
#   + Generando UPDATE para ID: 5129
#   + Generando UPDATE para ID: 5281
#   + Generando UPDATE para ID: 5290
#   + Generando UPDATE para ID: 6188
#   + Generando UPDATE para ID: 5319
#   + Generando UPDATE para ID: 5381
#   + Generando UPDATE para ID: 5382
#   + Generando UPDATE para ID: 5383
#   + Generando UPDATE para ID: 5384
#   + Generando UPDATE para ID: 7091
#   + Generando UPDATE para ID: 5429
#   ! Ignorando VOLUMEN para DOI '10.23919/CCC55666.2022.9902816': valor '2022-July' no es entero válido
#   + Generando UPDATE para ID: 5479
#   + Generando UPDATE para ID: 7093
#   + Generando UPDATE para ID: 5528
#   + Generando UPDATE para ID: 5589
#   + Generando UPDATE para ID: 6254
#   + Generando UPDATE para ID: 5649
#   + Generando UPDATE para ID: 5650
#   + Generando UPDATE para ID: 5653
#   + Generando UPDATE para ID: 5654
#   + Generando UPDATE para ID: 5657
#   + Generando UPDATE para ID: 5664
#   + Generando UPDATE para ID: 5666
#   + Generando UPDATE para ID: 5685
#   + Generando UPDATE para ID: 5758
#   + Generando UPDATE para ID: 5841
#   + Generando UPDATE para ID: 5893
#   + Generando UPDATE para ID: 5927
#   + Generando UPDATE para ID: 5941
#   + Generando UPDATE para ID: 5945
#   + Generando UPDATE para ID: 5948
#   + Generando UPDATE para ID: 6956
#   + Generando UPDATE para ID: 5955
#   + Generando UPDATE para ID: 4130
#   + Generando UPDATE para ID: 6191
#   + Generando UPDATE para ID: 6152
#   + Generando UPDATE para ID: 6154
#   + Generando UPDATE para ID: 6162
#   + Generando UPDATE para ID: 6163
#   + Generando UPDATE para ID: 6245
#   + Generando UPDATE para ID: 6265
#   + Generando UPDATE para ID: 6301
#   + Generando UPDATE para ID: 6352
#   + Generando UPDATE para ID: 6354
#   + Generando UPDATE para ID: 6361
#   + Generando UPDATE para ID: 6364
#   + Generando UPDATE para ID: 6381
#   + Generando UPDATE para ID: 6388
#   + Generando UPDATE para ID: 6389
#   + Generando UPDATE para ID: 6390
#   + Generando UPDATE para ID: 6452
#   + Generando UPDATE para ID: 6453
#   + Generando UPDATE para ID: 6251
#   + Generando UPDATE para ID: 6595
#   + Generando UPDATE para ID: 6604
#   + Generando UPDATE para ID: 6646
#   + Generando UPDATE para ID: 6713
#   + Generando UPDATE para ID: 6714
#   + Generando UPDATE para ID: 6820
#   + Generando UPDATE para ID: 6853
#   + Generando UPDATE para ID: 7043
#   + Generando UPDATE para ID: 7025
#   + Generando UPDATE para ID: 7047
#   + Generando UPDATE para ID: 7088
#   + Generando UPDATE para ID: 7095
#   + Generando UPDATE para ID: 7101
#   + Generando UPDATE para ID: 7149
#   + Generando UPDATE para ID: 7164
#   + Generando UPDATE para ID: 7998
#   + Generando UPDATE para ID: 7247
#   + Generando UPDATE para ID: 7251
#   + Generando UPDATE para ID: 7254
#   + Generando UPDATE para ID: 7255
#   + Generando UPDATE para ID: 7329
#   + Generando UPDATE para ID: 7999
#   + Generando UPDATE para ID: 7345
#   + Generando UPDATE para ID: 7358
#   + Generando UPDATE para ID: 7429
#   + Generando UPDATE para ID: 7488
#   + Generando UPDATE para ID: 7499
#   + Generando UPDATE para ID: 7503
#   + Generando UPDATE para ID: 7514
#   + Generando UPDATE para ID: 7584
#   + Generando UPDATE para ID: 7657
#   + Generando UPDATE para ID: 7676
#   + Generando UPDATE para ID: 7706
#   + Generando UPDATE para ID: 7725
#   + Generando UPDATE para ID: 7742
#   + Generando UPDATE para ID: 7823
#   + Generando UPDATE para ID: 7872
#   + Generando UPDATE para ID: 7873
#   + Generando UPDATE para ID: 7883
#   + Generando UPDATE para ID: 7885
#   + Generando UPDATE para ID: 7886
#   + Generando UPDATE para ID: 7904
#   + Generando UPDATE para ID: 7911
#   + Generando UPDATE para ID: 7913
#   + Generando UPDATE para ID: 7914
#   + Generando UPDATE para ID: 7934
#   + Generando UPDATE para ID: 8012
#   + Generando UPDATE para ID: 8016
#   + Generando UPDATE para ID: 8034
#   + Generando UPDATE para ID: 8114
#   + Generando UPDATE para ID: 8118
#   + Generando UPDATE para ID: 8120
#   + Generando UPDATE para ID: 8126
#   + Generando UPDATE para ID: 8144
#   + Generando UPDATE para ID: 8172
#   + Generando UPDATE para ID: 8189
#   + Generando UPDATE para ID: 8191
#   + Generando UPDATE para ID: 8216
#   + Generando UPDATE para ID: 8220
#   + Generando UPDATE para ID: 8238
#   + Generando UPDATE para ID: 8239
#   + Generando UPDATE para ID: 8240
#   + Generando UPDATE para ID: 8243
#   + Generando UPDATE para ID: 8244
#   + Generando UPDATE para ID: 8250
#   + Generando UPDATE para ID: 8258
#   + Generando UPDATE para ID: 8264
#   + Generando UPDATE para ID: 8271
#   + Generando UPDATE para ID: 8272
#   + Generando UPDATE para ID: 8288
#   + Generando UPDATE para ID: 8289
#   + Generando UPDATE para ID: 8315
#   + Generando UPDATE para ID: 8318
#   + Generando UPDATE para ID: 8319
#   + Generando UPDATE para ID: 8320
#   + Generando UPDATE para ID: 8322
#   + Generando UPDATE para ID: 8325
#   + Generando UPDATE para ID: 1327
#   + Generando UPDATE para ID: 110
#   + Generando UPDATE para ID: 50
#   + Generando UPDATE para ID: 81
#   + Generando UPDATE para ID: 82
#   + Generando UPDATE para ID: 83
#   + Generando UPDATE para ID: 168
#   + Generando UPDATE para ID: 137
#   + Generando UPDATE para ID: 100
#   + Generando UPDATE para ID: 123
#   + Generando UPDATE para ID: 169
#   + Generando UPDATE para ID: 129
#   + Generando UPDATE para ID: 130
#   + Generando UPDATE para ID: 131
#   + Generando UPDATE para ID: 132
#   + Generando UPDATE para ID: 1596
#   + Generando UPDATE para ID: 789
#   + Generando UPDATE para ID: 201
#   + Generando UPDATE para ID: 226
#   + Generando UPDATE para ID: 248
#   + Generando UPDATE para ID: 261
#   + Generando UPDATE para ID: 262
#   + Generando UPDATE para ID: 268
#   + Generando UPDATE para ID: 269
#   + Generando UPDATE para ID: 271
#   + Generando UPDATE para ID: 272
#   + Generando UPDATE para ID: 285
#   + Generando UPDATE para ID: 292
#   + Generando UPDATE para ID: 295
#   + Generando UPDATE para ID: 309
#   + Generando UPDATE para ID: 310
#   + Generando UPDATE para ID: 303
#   + Generando UPDATE para ID: 303
#   + Generando UPDATE para ID: 440
#   + Generando UPDATE para ID: 305
#   + Generando UPDATE para ID: 325
#   + Generando UPDATE para ID: 335
#   + Generando UPDATE para ID: 379
#   + Generando UPDATE para ID: 381
#   + Generando UPDATE para ID: 382
#   + Generando UPDATE para ID: 385
#   + Generando UPDATE para ID: 404
#   + Generando UPDATE para ID: 405
#   + Generando UPDATE para ID: 406
#   + Generando UPDATE para ID: 407
#   + Generando UPDATE para ID: 408
#   + Generando UPDATE para ID: 409
#   + Generando UPDATE para ID: 411
#   + Generando UPDATE para ID: 412
#   + Generando UPDATE para ID: 413
#   + Generando UPDATE para ID: 414
#   + Generando UPDATE para ID: 415
#   + Generando UPDATE para ID: 416
#   + Generando UPDATE para ID: 421
#   + Generando UPDATE para ID: 422
#   + Generando UPDATE para ID: 426
#   + Generando UPDATE para ID: 480
#   + Generando UPDATE para ID: 502
#   + Generando UPDATE para ID: 526
#   + Generando UPDATE para ID: 529
#   + Generando UPDATE para ID: 535
#   + Generando UPDATE para ID: 543
#   + Generando UPDATE para ID: 544
#   + Generando UPDATE para ID: 545
#   + Generando UPDATE para ID: 550
#   + Generando UPDATE para ID: 566
#   + Generando UPDATE para ID: 567
#   ! Ignorando VOLUMEN para DOI '10.1109/ChiCC.2016.7554385': valor '2016-August' no es entero válido
#   + Generando UPDATE para ID: 589
#   + Generando UPDATE para ID: 602
#   + Generando UPDATE para ID: 609
#   + Generando UPDATE para ID: 611
#   + Generando UPDATE para ID: 692
#   + Generando UPDATE para ID: 646
#   + Generando UPDATE para ID: 717
#   + Generando UPDATE para ID: 727
#   + Generando UPDATE para ID: 747
#   + Generando UPDATE para ID: 760
#   + Generando UPDATE para ID: 766
#   + Generando UPDATE para ID: 778
#   + Generando UPDATE para ID: 786
#   + Generando UPDATE para ID: 1222
#   + Generando UPDATE para ID: 1223
#   + Generando UPDATE para ID: 805
#   + Generando UPDATE para ID: 806
#   + Generando UPDATE para ID: 807
#   + Generando UPDATE para ID: 809
#   + Generando UPDATE para ID: 813
#   + Generando UPDATE para ID: 814
#   + Generando UPDATE para ID: 819
#   + Generando UPDATE para ID: 820
#   + Generando UPDATE para ID: 821
#   + Generando UPDATE para ID: 822
#   + Generando UPDATE para ID: 823
#   + Generando UPDATE para ID: 824
#   + Generando UPDATE para ID: 825
#   + Generando UPDATE para ID: 837
#   + Generando UPDATE para ID: 842
#   + Generando UPDATE para ID: 973
#   + Generando UPDATE para ID: 846
#   + Generando UPDATE para ID: 862
#   + Generando UPDATE para ID: 854
#   + Generando UPDATE para ID: 864
#   + Generando UPDATE para ID: 876
#   + Generando UPDATE para ID: 886
#   + Generando UPDATE para ID: 974
#   + Generando UPDATE para ID: 899
#   + Generando UPDATE para ID: 905
#   + Generando UPDATE para ID: 909
#   + Generando UPDATE para ID: 911
#   + Generando UPDATE para ID: 912
#   + Generando UPDATE para ID: 913
#   + Generando UPDATE para ID: 914
#   + Generando UPDATE para ID: 915
#   + Generando UPDATE para ID: 918
#   + Generando UPDATE para ID: 920
#   + Generando UPDATE para ID: 921
#   + Generando UPDATE para ID: 923
#   + Generando UPDATE para ID: 926
#   + Generando UPDATE para ID: 927
#   + Generando UPDATE para ID: 930
#   + Generando UPDATE para ID: 933
#   + Generando UPDATE para ID: 934
#   + Generando UPDATE para ID: 935
#   + Generando UPDATE para ID: 952
#   + Generando UPDATE para ID: 953
#   + Generando UPDATE para ID: 955
#   + Generando UPDATE para ID: 956
#   + Generando UPDATE para ID: 970
#   + Generando UPDATE para ID: 977
#   + Generando UPDATE para ID: 978
#   + Generando UPDATE para ID: 979
#   + Generando UPDATE para ID: 980
#   + Generando UPDATE para ID: 1070
#   + Generando UPDATE para ID: 985
#   + Generando UPDATE para ID: 986
#   + Generando UPDATE para ID: 987
#   + Generando UPDATE para ID: 988
#   + Generando UPDATE para ID: 989
#   + Generando UPDATE para ID: 990
#   + Generando UPDATE para ID: 991
#   + Generando UPDATE para ID: 995
#   + Generando UPDATE para ID: 996
#   + Generando UPDATE para ID: 1000
#   + Generando UPDATE para ID: 1004
#   + Generando UPDATE para ID: 1010
#   + Generando UPDATE para ID: 1012
#   + Generando UPDATE para ID: 1013
#   + Generando UPDATE para ID: 1014
#   + Generando UPDATE para ID: 1015
#   + Generando UPDATE para ID: 1016
#   + Generando UPDATE para ID: 1017
#   + Generando UPDATE para ID: 1019
#   + Generando UPDATE para ID: 1020
#   + Generando UPDATE para ID: 1024
#   + Generando UPDATE para ID: 1026
#   + Generando UPDATE para ID: 1027
#   + Generando UPDATE para ID: 1028
#   + Generando UPDATE para ID: 1029
#   + Generando UPDATE para ID: 1037
#   + Generando UPDATE para ID: 1038
#   + Generando UPDATE para ID: 1039
#   + Generando UPDATE para ID: 1046
#   + Generando UPDATE para ID: 1047
#   + Generando UPDATE para ID: 1049
#   + Generando UPDATE para ID: 1050
#   + Generando UPDATE para ID: 1050
#   + Generando UPDATE para ID: 1051
#   + Generando UPDATE para ID: 1052
#   + Generando UPDATE para ID: 1053
#   + Generando UPDATE para ID: 1060
#   + Generando UPDATE para ID: 1063
#   + Generando UPDATE para ID: 1064
#   + Generando UPDATE para ID: 1065
#   + Generando UPDATE para ID: 1068
#   + Generando UPDATE para ID: 103
#   + Generando UPDATE para ID: 1072
#   + Generando UPDATE para ID: 929
#   + Generando UPDATE para ID: 1080
#   + Generando UPDATE para ID: 1081
#   + Generando UPDATE para ID: 1083
#   + Generando UPDATE para ID: 1092
#   + Generando UPDATE para ID: 1093
#   + Generando UPDATE para ID: 1103
#   + Generando UPDATE para ID: 1108
#   + Generando UPDATE para ID: 1110
#   + Generando UPDATE para ID: 1111
#   + Generando UPDATE para ID: 1116
#   + Generando UPDATE para ID: 1119
#   + Generando UPDATE para ID: 1120
#   + Generando UPDATE para ID: 1121
#   + Generando UPDATE para ID: 1122
#   + Generando UPDATE para ID: 1123
#   + Generando UPDATE para ID: 1139
#   + Generando UPDATE para ID: 1139
#   + Generando UPDATE para ID: 1141
#   + Generando UPDATE para ID: 1142
#   + Generando UPDATE para ID: 1646
#   + Generando UPDATE para ID: 118
#   + Generando UPDATE para ID: 1185
#   + Generando UPDATE para ID: 1186
#   + Generando UPDATE para ID: 1190
#   + Generando UPDATE para ID: 1200
#   + Generando UPDATE para ID: 1201
#   + Generando UPDATE para ID: 1203
#   + Generando UPDATE para ID: 1204
#   + Generando UPDATE para ID: 1228
#   + Generando UPDATE para ID: 1259
#   + Generando UPDATE para ID: 1269
#   + Generando UPDATE para ID: 1273
#   + Generando UPDATE para ID: 1286
#   + Generando UPDATE para ID: 1287
#   + Generando UPDATE para ID: 1291
#   + Generando UPDATE para ID: 1299
#   + Generando UPDATE para ID: 1300
#   + Generando UPDATE para ID: 1314
#   + Generando UPDATE para ID: 1331
#   + Generando UPDATE para ID: 1732
#   + Generando UPDATE para ID: 1333
#   + Generando UPDATE para ID: 2066
#   + Generando UPDATE para ID: 1344
#   + Generando UPDATE para ID: 1350
#   + Generando UPDATE para ID: 1363
#   + Generando UPDATE para ID: 1364
#   + Generando UPDATE para ID: 1386
#   + Generando UPDATE para ID: 1388
#   + Generando UPDATE para ID: 1393
#   + Generando UPDATE para ID: 1398
#   + Generando UPDATE para ID: 1403
#   + Generando UPDATE para ID: 1404
#   + Generando UPDATE para ID: 1410
#   + Generando UPDATE para ID: 1411
#   + Generando UPDATE para ID: 1413
#   + Generando UPDATE para ID: 1414
#   + Generando UPDATE para ID: 1415
#   + Generando UPDATE para ID: 1424
#   + Generando UPDATE para ID: 1438
#   + Generando UPDATE para ID: 1451
#   + Generando UPDATE para ID: 1453
#   + Generando UPDATE para ID: 1453
#   + Generando UPDATE para ID: 1475
#   + Generando UPDATE para ID: 1476
#   + Generando UPDATE para ID: 1477
#   + Generando UPDATE para ID: 1479
#   + Generando UPDATE para ID: 1480
#   + Generando UPDATE para ID: 1481
#   + Generando UPDATE para ID: 1483
#   + Generando UPDATE para ID: 1488
#   + Generando UPDATE para ID: 1494
#   + Generando UPDATE para ID: 1500
#   + Generando UPDATE para ID: 1503
#   + Generando UPDATE para ID: 1504
#   + Generando UPDATE para ID: 1505
#   + Generando UPDATE para ID: 1507
#   + Generando UPDATE para ID: 1510
#   + Generando UPDATE para ID: 1512
#   + Generando UPDATE para ID: 1518
#   + Generando UPDATE para ID: 1519
#   + Generando UPDATE para ID: 1529
#   + Generando UPDATE para ID: 1532
#   + Generando UPDATE para ID: 1786
#   + Generando UPDATE para ID: 1540
#   + Generando UPDATE para ID: 1543
#   + Generando UPDATE para ID: 1544
#   + Generando UPDATE para ID: 1545
#   + Generando UPDATE para ID: 1546
#   + Generando UPDATE para ID: 1547
#   + Generando UPDATE para ID: 1550
#   + Generando UPDATE para ID: 1570
#   + Generando UPDATE para ID: 1572
#   + Generando UPDATE para ID: 1573
#   + Generando UPDATE para ID: 1576
#   + Generando UPDATE para ID: 1577
#   + Generando UPDATE para ID: 1580
#   + Generando UPDATE para ID: 1582
#   + Generando UPDATE para ID: 1583
#   + Generando UPDATE para ID: 1584
#   + Generando UPDATE para ID: 1585
#   + Generando UPDATE para ID: 1586
#   + Generando UPDATE para ID: 1587
#   + Generando UPDATE para ID: 1588
#   + Generando UPDATE para ID: 166
#   + Generando UPDATE para ID: 1330
#   + Generando UPDATE para ID: 1263
#   + Generando UPDATE para ID: 1639
#   + Generando UPDATE para ID: 1641
#   + Generando UPDATE para ID: 1655
#   + Generando UPDATE para ID: 1657
#   + Generando UPDATE para ID: 1663
#   + Generando UPDATE para ID: 1676
#   + Generando UPDATE para ID: 1705
#   + Generando UPDATE para ID: 1695
#   + Generando UPDATE para ID: 1696
#   + Generando UPDATE para ID: 1707
#   + Generando UPDATE para ID: 1712
#   + Generando UPDATE para ID: 1724
#   + Generando UPDATE para ID: 1746
#   + Generando UPDATE para ID: 1752
#   + Generando UPDATE para ID: 1753
#   + Generando UPDATE para ID: 1760
#   + Generando UPDATE para ID: 1769
#   + Generando UPDATE para ID: 1770
#   + Generando UPDATE para ID: 1772
#   + Generando UPDATE para ID: 1773
#   + Generando UPDATE para ID: 1776
#   + Generando UPDATE para ID: 1777
#   + Generando UPDATE para ID: 1778
#   + Generando UPDATE para ID: 1780
#   + Generando UPDATE para ID: 1782
#   + Generando UPDATE para ID: 1998
#   + Generando UPDATE para ID: 1868
#   + Generando UPDATE para ID: 1872
#   + Generando UPDATE para ID: 1880
#   + Generando UPDATE para ID: 1896
#   + Generando UPDATE para ID: 1902
#   + Generando UPDATE para ID: 1903
#   + Generando UPDATE para ID: 1916
#   + Generando UPDATE para ID: 1920
#   + Generando UPDATE para ID: 1921
#   + Generando UPDATE para ID: 1922
#   + Generando UPDATE para ID: 1938
#   + Generando UPDATE para ID: 1955
#   + Generando UPDATE para ID: 1987
#   + Generando UPDATE para ID: 1992
#   + Generando UPDATE para ID: 1993
#   + Generando UPDATE para ID: 1994
#   + Generando UPDATE para ID: 1996
#   + Generando UPDATE para ID: 2037
#   + Generando UPDATE para ID: 2043
#   + Generando UPDATE para ID: 2049
#   + Generando UPDATE para ID: 2167
#   + Generando UPDATE para ID: 2171
#   + Generando UPDATE para ID: 2172
#   + Generando UPDATE para ID: 2234
#   + Generando UPDATE para ID: 2299
#   + Generando UPDATE para ID: 2300
#   + Generando UPDATE para ID: 2301
#   + Generando UPDATE para ID: 2303

# %% [markdown]
# Escritura del archivo .sql final

# %%
output_filename = 'update_script.sql'
with open(output_filename, 'w', encoding='utf-8') as f:
    if not sql_update_commands:
        f.write("-- No se encontraron registros que requieran actualización según las reglas especificadas.\n")
    else:
        f.write(f"-- Script de actualización generado automáticamente.\n")
        f.write(f"-- Total de registros a actualizar: {len(sql_update_commands)}\n\n")
        for command in sql_update_commands:
            f.write(command + '\n')

print(f"\n¡Proceso completado! El script de actualización se ha guardado en '{output_filename}'")
# Out:
# ¡Proceso completado! El script de actualización se ha guardado en 'update_script.sql'
